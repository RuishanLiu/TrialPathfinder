# %% [markdown]
# # Extract the useful subset of studies from trial complexity data
#
# Created by: Shemra Rizzo
# Date created: Nov 24, 2020

# %%
# Libraries
import pandas as pd
import numpy as np

# %%
#trial_complexity_data = pd.read_csv('trial_complexity.csv')

trial_complexity_data = pd.read_csv('STUDYGO_24_06_2020.csv')

# %%
trial_complexity_data.shape
# Out:
# (2304, 212)

# %%
studies_in_supplement = [
'MO25515',
'NO25390',
'GO28053',
'GO28625',
'GO28754',
'YO29232',
'YO29233',
'GO40241',
'ML40471',
'BO22334',
'GO01298',
'YP25623',
'ML29167',
'ML29538',
'MO27782',
'MO28113',
'ML28589',
'ML28879',
'ML28794',
'GO29058',
'ML29282',
'YO29296',
'ML29662',
'GO30182',
'CO39083'
]

# %%
subset = trial_complexity_data[trial_complexity_data['STUDY_NUMBER'].isin(studies_in_supplement)]

# %%
columns_of_interest = ['STUDY_NUMBER', 'STUDY_FULL_TITLE', 'STUDY_SHORT_TITLE',
       'STUDY_ACRONIM', 'STUDY_STATUS', 'DB_LOCK_FLAG', 'STUDY_PHASE_GROUP',
       'STUDY_PHASE', 'STUDY_TYPE', 'THERAPEUTIC_AREA_REP', 'THERAPEUTIC_AREA',
       'DTA', 'INDICATION', 'INDICATION_REP', 'DISTRIBUTION', 'COMPARISON',
       'RANDOMIZATION', 'INTERVENTIONAL_STUDY_MODEL', 'BLINDING',
       'EXECUTING_PARTY', 'OUTSOURCED', 'TARGET_NUM_COUNTRIES', 'OBJECTIVE',
       'STUDY_KEYWORDS', 'INCLUSION_CRITERIA', 'NUM_OF_DRAGS', 'DRUG_PRIMARY_NAME',
       'DRUG_NAMES', 'THERAPEUTIC_CLASSES', 'ACTUAL_ENROLLED_STUDY', 'PLANNED_ENROLLMENT',
                       'WITHDRAWAL_RATIO' , 'SCREENING_RATE',
       'ENROLLMENT_RATE', 'SCREEN_FAIL_RATIO', 'NUM_ALL_AE', 'NUM_AE',
       'NUM_SAE', 'SCREENING_SUCCESS_RATIO',
       'SCREEN_FAIL_DECLINED_TO_PARTICIPATE', 'SCREEN_FAIL_INCLUSION',
       'SCREEN_FAIL_EXCLUSION', 'WITHDRAWN_ADVERSE_EVENTS',
       'WITHDRAWN_SUBJECTIVE', 'WITHDRAWN_NON_COMPLIANCE',
       'WITHDRAWN_PROTOCOL_DEVIATIONS', 'WITHDRAWN_SAFETY',
       'WITHDRAWN_OTHER_PRE_SPECIFIED', 'WITHDRAWN_OTHER',
       'WITHDRAWN_ADVERSE_EVENTS_RATIO', 'WITHDRAWN_SUBJECTIVE_RATIO',
       'WITHDRAWN_NON_COMPLIANCE_RATIO', 'WITHDRAWN_PROTOCOL_DEVIATIONS_RATIO',
       'WITHDRAWN_SAFETY_RATIO', 'WITHDRAWN_OTHER_PRE_SPECIFIED_RATIO',
       'WITHDRAWN_OTHER_RATIO']

# %%
subset = subset[columns_of_interest]

# %%
# save subset
subset.to_csv('trial_pathfinder_subset_in_supplement.csv')

# %%
trial_complexity_data.columns[0:50]
# Out:
# Index(['STUDY_NUMBER', 'STUDY_FULL_TITLE', 'STUDY_SHORT_TITLE',
#        'STUDY_ACRONIM', 'STUDY_STATUS', 'DB_LOCK_FLAG', 'STUDY_PHASE_GROUP',
#        'STUDY_PHASE', 'STUDY_TYPE', 'THERAPEUTIC_AREA_REP', 'THERAPEUTIC_AREA',
#        'DTA', 'INDICATION', 'INDICATION_REP', 'DISTRIBUTION', 'COMPARISON',
#        'RANDOMIZATION', 'INTERVENTIONAL_STUDY_MODEL', 'BLINDING',
#        'EXECUTING_PARTY', 'OUTSOURCED', 'TARGET_NUM_COUNTRIES', 'OBJECTIVE',
#        'STUDY_KEYWORDS', 'INCLUSION_CRITERIA', 'EXCLUSION_CRITERIA',
#        'PAT_CRIT_MIN_AGE', 'PAT_CRIT_MAX_AGE', 'PAT_CRIT_GENDER',
#        'ACTUAL_TREATMENT_DURATION', 'NUM_OF_DRAGS', 'DRUG_PRIMARY_NAME',
#        'DRUG_NAMES', 'THERAPEUTIC_CLASSES', 'NUM_PRIMARY_ENDPOINTS',
#        'NUM_SECONDARY_ENDPOINTS', 'PRIMARY_ENDPOINTS', 'SECONDARY_ENDPOINTS',
#        'NUM_OF_ARMS', 'LIST_OF_ARMS', 'NUM_BIOMARKERS', 'LIST_BIOMARKERS',
#        'NUM_ACTUAL_STUDY_SITES', 'NUM_PLANNED_STUDY_SITES',
#        'ACTUAL_ENROLLED_STUDY', 'PLANNED_ENROLLMENT', 'WITHDRAWAL_RATIO',
#        'CYCLES', 'NR_PRIMARY_INVESTIGATORS', 'NUM_PROTOCOL_VERSION'],
#       dtype='object')

# %%
subset.columns
# Out:
# Index(['STUDY_NUMBER', 'STUDY_FULL_TITLE', 'STUDY_SHORT_TITLE',
#        'STUDY_ACRONIM', 'STUDY_STATUS', 'DB_LOCK_FLAG', 'STUDY_PHASE_GROUP',
#        'STUDY_PHASE', 'STUDY_TYPE', 'THERAPEUTIC_AREA_REP', 'THERAPEUTIC_AREA',
#        'DTA', 'INDICATION', 'INDICATION_REP', 'DISTRIBUTION', 'COMPARISON',
#        'RANDOMIZATION', 'INTERVENTIONAL_STUDY_MODEL', 'BLINDING',
#        'EXECUTING_PARTY', 'OUTSOURCED', 'TARGET_NUM_COUNTRIES', 'OBJECTIVE',
#        'STUDY_KEYWORDS', 'INCLUSION_CRITERIA', 'NUM_OF_DRAGS',
#        'DRUG_PRIMARY_NAME', 'DRUG_NAMES', 'THERAPEUTIC_CLASSES',
#        'WITHDRAWAL_RATIO', 'SCREENING_RATE', 'ENROLLMENT_RATE',
#        'SCREEN_FAIL_RATIO', 'NUM_ALL_AE', 'NUM_AE', 'NUM_SAE',
#        'SCREENING_SUCCESS_RATIO', 'SCREEN_FAIL_DECLINED_TO_PARTICIPATE',
#        'SCREEN_FAIL_INCLUSION', 'SCREEN_FAIL_EXCLUSION',
#        'WITHDRAWN_ADVERSE_EVENTS', 'WITHDRAWN_SUBJECTIVE',
#        'WITHDRAWN_NON_COMPLIANCE', 'WITHDRAWN_PROTOCOL_DEVIATIONS',
#        'WITHDRAWN_SAFETY', 'WITHDRAWN_OTHER_PRE_SPECIFIED', 'WITHDRAWN_OTHER',
#        'WITHDRAWN_ADVERSE_EVENTS_RATIO', 'WITHDRAWN_SUBJECTIVE_RATIO',
#        'WITHDRAWN_NON_COMPLIANCE_RATIO', 'WITHDRAWN_PROTOCOL_DEVIATIONS_RATIO',
#        'WITHDRAWN_SAFETY_RATIO', 'WITHDRAWN_OTHER_PRE_SPECIFIED_RATIO',
#        'WITHDRAWN_OTHER_RATIO'],
#       dtype='object')

# %%
subset
# Out:
#      STUDY_NUMBER                                   STUDY_FULL_TITLE  \
# 67        GO40241  A PHASE III, DOUBLE-BLINDED, MULTICENTER, RAND...
# 145       YO29233  A PHASE I, OPEN-LABEL STUDY TO ASSESS THE PHAR...
# 192       MO28113  A TWO-PART, RANDOMIZED PHASE III, DOUBLE-BLIND...
# 209       ML29282  A PHASE IV, MULTICENTER, OPEN-LABEL, SINGLE-AR...
# 215       YP25623  A multi-center, open label, single arm, multip...
# 319       YO29232  A PHASE III, OPEN-LABEL, MULTICENTER, RANDOMIZ...
# 354       ML28794  Single arm multi-center study investigating th...
# 654       ML28589  An open-label, multicenter Phase IIIb study in...
# 866       ML28879  National Phase IIIB Prospective ,  Two-Cohort ...
# 997       YO29296  A PHASE III, RANDOMIZED, DOUBLE-BLIND, PLACEBO...
# 1007      GO28053  An Open Label, Phase I Study to Evaluate the I...
# 1028      GO28754  A PHASE II, MULTICENTER, SINGLE-ARM STUDY OF M...
# 1135      NO25390  An open-label, multicenter, single-arm, Phase ...
# 1140      ML29662  A MULTICENTER, OPEN-LABEL, SINGLE-ARM, PHASE I...
# 1352      MO25515  An open-label, multicenter expanded access stu...
# 1489      GO29058  A PHASE III, DOUBLE-BLIND, PLACEBO-CONTROLLED,...
# 1513      GO30182  A PHASE III, OPEN-LABEL, MULTICENTER, THREE-AR...
# 1525      ML40471  An Open-Label, Single arm, Multicenter Study t...
# 1665      ML29538  An Open-Label Study of Obinutuzumab (GA101) Pl...
# 1848      GO28625  A PHASE II, MULTICENTER, SINGLE-ARM STUDY OF A...
# 2004      CO39083  A PHASE Ib OPEN-LABEL STUDY EVALUATING THE SAF...
# 2107      BO22334  A phase III study of SC rituximab in combinati...
# 2126      GO01298  AN OPEN-LABEL, MULTICENTER, PHASE Ib TRIAL OF ...
# 2200      MO27782  A two-cohort, open-label, multicenter Phase II...
# 2225      ML29167  PHASE II TRIAL TO EVALUATE THE EFFICACY OF OBI...
#
#                                       STUDY_SHORT_TITLE      STUDY_ACRONIM  \
# 67                                    Neoadjuvant NSCLC                NaN
# 145                                     China PK  Study                NaN
# 192       Pertuzumab + chemo+: platinum resistant women           PENELOPE
# 209     Open-label single arm study in first line advBC                NaN
# 215               PK study of GA101 in Chinese patients           GERSHWIN
# 319   China 2/3 Non Small Cell Lung Cancer Regional ...                NaN
# 354                              UMBHER1 Umbrella_BELIS                NaN
# 654   UmbHER1- Herceptin SC Preference/Safety in Her...                NaN
# 866          UMBHER 1 Umbrella Safety of trastuzumab sc                NaN
# 997           Perjeta China regional 1L MBC HER2+ study                NaN
# 1007  Zelboraf Severe Hepatic Impairment Study (PMR #6)            Hepatic
# 1028         aPDL1 PHASE II in PD-L1-POSITIVE NSCLC pts              Birch
# 1135  RO5185426 in pediatric pats in BRAFV600E melanoma             BRIM-P
# 1140                       HER2+ ADVANCED BREAST CANCER                NaN
# 1352  Study of RO5185426 in metastatic melanoma pati...                NaN
# 1489       GDC-0032 HER2- HR+ phase III (LIP phase III)          SANDPIPER
# 1513  Phase 3 cobimetinib in combination with atezol...  COTEZO IMblaze370
# 1525  Atezolizumab's long-term safety in previously-...                NaN
# 1665                      Gazyva (GA101) Plus Benda CLL                NaN
# 1848            Phase II Trial of Atezolizumab in NSCLC                FIR
# 2004  A PHASE Ib OPEN-LABEL STUDY EVALUATING THE SAF...                NaN
# 2107                Ph III of MabThera SC w CHOP or CVP            SABRINA
# 2126  Ph 1b- 1st Line CLL GA101 chemo combo safety s...             GALTON
# 2200  VELVET: Pertu+/-Trastu + Vino, 1st line Her2+ mBC             VELVET
# 2225  Efficacy Obinutuzumab+ Benda in refract/relaps...                NaN
#
#           STUDY_STATUS  DB_LOCK_FLAG STUDY_PHASE_GROUP STUDY_PHASE  \
# 67              Active             0           Phase 3   Phase III
# 145             Active             0           Phase 1    Phase Ib
# 192   Clinical Closure             1           Phase 3   Phase III
# 209   Clinical Closure             1           Phase 4    Phase IV
# 215   Clinical Closure             1           Phase 1     Phase I
# 319             Active             0           Phase 3   Phase III
# 354   Clinical Closure             1           Phase 3   Phase III
# 654             Active             1           Phase 3   Phase III
# 866   Clinical Closure             1           Phase 3   Phase III
# 997             Active             0           Phase 3   Phase III
# 1007  Clinical Closure             1           Phase 1     Phase I
# 1028  Clinical Closure             1           Phase 2    Phase II
# 1135  Clinical Closure             1           Phase 1     Phase I
# 1140            Active             1           Phase 4    Phase IV
# 1352  Clinical Closure             1           Phase 3   Phase III
# 1489            Active             0           Phase 3   Phase III
# 1513  Clinical Closure             1           Phase 3   Phase III
# 1525            Active             0           Phase 3   Phase III
# 1665            Active             1           Phase 2    Phase II
# 1848  Clinical Closure             1           Phase 2    Phase II
# 2004  Clinical Closure             1           Phase 1    Phase Ib
# 2107  Clinical Closure             1           Phase 3   Phase III
# 2126  Clinical Closure             1           Phase 1    Phase Ib
# 2200  Clinical Closure             1           Phase 2    Phase II
# 2225  Clinical Closure             1           Phase 2    Phase II
#
#           STUDY_TYPE THERAPEUTIC_AREA_REP  ... WITHDRAWN_SAFETY  \
# 67    Interventional                  ONC  ...              0.0
# 145   Interventional                  ONC  ...              0.0
# 192   Interventional                  ONC  ...              0.0
# 209   Interventional                  ONC  ...              0.0
# 215   Interventional                  ONC  ...              0.0
# 319   Interventional                  ONC  ...              0.0
# 354   Interventional                  ONC  ...              0.0
# 654   Interventional                  ONC  ...              0.0
# 866   Interventional                  ONC  ...              0.0
# 997   Interventional                  ONC  ...              0.0
# 1007  Interventional                  ONC  ...              0.0
# 1028  Interventional                  ONC  ...              0.0
# 1135  Interventional                  ONC  ...              0.0
# 1140  Interventional                  ONC  ...              0.0
# 1352  Interventional                  ONC  ...              0.0
# 1489  Interventional                  ONC  ...              0.0
# 1513  Interventional                  ONC  ...              0.0
# 1525  Interventional                  ONC  ...              0.0
# 1665  Interventional                  ONC  ...              0.0
# 1848  Interventional                  ONC  ...              0.0
# 2004  Interventional                  ONC  ...              0.0
# 2107  Interventional                  ONC  ...              0.0
# 2126  Interventional                  ONC  ...              0.0
# 2200  Interventional                  ONC  ...              0.0
# 2225  Interventional                  ONC  ...              0.0
#
#      WITHDRAWN_OTHER_PRE_SPECIFIED WITHDRAWN_OTHER  \
# 67                             0.0            23.0
# 145                            0.0            85.0
# 192                            0.0            37.0
# 209                            0.0             1.0
# 215                            0.0            14.0
# 319                            0.0           431.0
# 354                            0.0             3.0
# 654                            0.0             8.0
# 866                            0.0            10.0
# 997                            0.0            71.0
# 1007                           0.0             9.0
# 1028                          89.0           496.0
# 1135                           0.0             4.0
# 1140                           0.0            32.0
# 1352                           0.0             2.0
# 1489                           0.0           513.0
